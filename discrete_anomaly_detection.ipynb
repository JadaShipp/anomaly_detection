# %%
from __future__ import division
import itertools
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import pandas as pd
import math
from sklearn import metrics
from random import randint
from matplotlib import style
import seaborn as sns
# %matplotlib inline
# code to regulate the size of plots for the rest of notebook
plt.rc('figure', figsize=(14, 12))
plt.rc('font', size=13)

# %%
colnames=['timestamp', 'time', 'destination', 'user', 'cohort',
          'ip', 'huh']
df = pd.read_csv('curriculum-access.txt',          
                 engine='python',
                 header=None,
                 index_col=False,
                 names=colnames,
                 error_bad_lines=False,
                 sep=r'\s(?=(?:[^"]*"[^"]*")*[^"]*$)(?![^\[]*\])',
                 na_values='"-"')

# %%
df
# Out:
#          timestamp      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 543591  2020-05-15  15:01:40
# 543592  2020-05-15  15:01:54
# 543593  2020-05-15  15:03:37
# 543594  2020-05-15  15:05:14
# 543595  2020-05-15  15:06:05
#
#                                               destination  user  cohort  \
# 0                                                       /     1     8.0
# 1                                                 java-ii     1     8.0
# 2                     java-ii/object-oriented-programming     1     8.0
# 3                      slides/object_oriented_programming     1     8.0
# 4                               javascript-i/conditionals     2    22.0
# ...                                                   ...   ...     ...
# 543591                                    java-ii/file-io   602    56.0
# 543592                                9-timeseries/3-prep   582    55.0
# 543593                 jquery/ajax/requests-and-responses   637    57.0
# 543594  10-anomaly-detection/3-discrete-probabilistic-...    11    28.0
# 543595                      examples/javascript/blog.json   643    57.0
#
#                     ip  huh
# 0         98.106.20.62  NaN
# 1         98.106.20.62  NaN
# 2         98.106.20.62  NaN
# 3         98.106.20.62  NaN
# 4         98.106.20.62  NaN
# ...                ...  ...
# 543591   48.188.241.68  NaN
# 543592   48.135.163.38  NaN
# 543593    71.121.18.17  NaN
# 543594  77.186.132.227  NaN
# 543595  174.175.131.39  NaN
#
# [543596 rows x 7 columns]

# %%
# df['Timestamp'] = df['timestamp'] + " " + df['time']
# df = df.drop(columns = ['timestamp', 'time', 'huh'])
# df['Timestamp'] = pd.to_datetime(df['Timestamp'])
# df = df.sort_values("Timestamp")
# df.head()

# %% [markdown]
# ## Let's do some anomaly detection column by column

# %% [markdown]
# ### Destination Column:
# - Get a look at the data
# > - Are there any nulls?
# > - Are there any unexpected values?
# > - What are the most and least frequently visited pages?

# %%
# get the observations where the nulls are occured
df.loc[df.destination.isnull()]
# Out:
#          timestamp      time destination  user  cohort             ip  huh
# 506305  2020-04-08  09:25:18         NaN   586    55.0  73.178.241.52  NaN

# %%
# drop this column
df.drop(df.index[[506305]], inplace=True)

# %%
df.destination.value_counts()
# Out:
# /                                              28920
# javascript-i                                   10950
# search/search_index.json                       10859
# toc                                             9839
# html-css                                        8202
#                                                ...
# ,%20https://github.com/RaulCPena                   1
# 4.2-compare-means                                  1
# html-css/positioning                               1
# content/php_iii/alternative-syntax.html            1
# content/examples/php/internal_functions.php        1
# Name: destination, Length: 1811, dtype: int64

# %%
df.groupby(['destination', 'cohort']).user.value_counts()
# Out:
# destination                       cohort  user
# %20https://github.com/RaulCPena   55.0    580       1
# ,%20https://github.com/RaulCPena  55.0    580       1
# .git                              24.0    203       1
# .gitignore                        24.0    203       1
# /                                 1.0     11      237
#                                                  ...
# web-design/ux/purpose             57.0    643       2
#                                           627       1
#                                           640       1
# wp-admin                          22.0    180       1
# wp-login                          22.0    180       1
# Name: user, Length: 72039, dtype: int64

# %% [markdown]
# - Can you label students who are viewing both the web dev and data science curriculum?
# - Can you label students by the program they are in? Can you label users by student vs. staff?
# - What are Zach, Maggie, David, and Ryan's ids?
# - Can you label students who are viewing both the web dev and data science curriculum?
# - Can you label students by the program they are in?
# - Can you label users by student vs. staff?

# %%
df.user.nunique()
# Out:
# 650

# %%
web_dev = df[df['destination'].str.contains('web')]
web_dev
# Out:
#          timestamp      time                                    destination  \
# 4831    2018-02-03  10:52:29          appendix/postwork/website-status-page
# 5218    2018-02-05  07:49:33          appendix/postwork/website-status-page
# 6972    2018-02-07  19:12:33          appendix/postwork/website-status-page
# 9136    2018-02-13  00:08:19          appendix/postwork/website-status-page
# 11436   2018-02-19  13:09:13          appendix/postwork/website-status-page
# ...            ...       ...                                            ...
# 537503  2020-05-08  12:36:45                          web-design/ui/visuals
# 537504  2020-05-08  12:36:46                          web-design/ux/purpose
# 537505  2020-05-08  12:36:48                           web-design/ux/layout
# 538760  2020-05-11  08:59:01                               web-design/intro
# 542832  2020-05-14  21:40:36  appendix/extra-challenges/website-status-page
#
#         user  cohort               ip  huh
# 4831      19    22.0      97.9.151.24  NaN
# 5218       9    22.0     98.106.20.62  NaN
# 6972      36    21.0   174.175.160.46  NaN
# 9136       4    22.0   71.124.232.212  NaN
# 11436     78     NaN     98.106.20.62  NaN
# ...      ...     ...              ...  ...
# 537503   524    52.0  109.200.118.236  NaN
# 537504   524    52.0  109.200.118.236  NaN
# 537505   524    52.0  109.200.118.236  NaN
# 538760   641    57.0    68.12.212.116  NaN
# 542832   638    57.0      71.115.1.53  NaN
#
# [1829 rows x 7 columns]

# %%
def get_topic(destination):
    ds_list = ["python", "time series", "nlp"]
    web_dev = ["javascript", "java", "css"]
    for ds in ds_list:
        if ds in destination:
            return "Data Science"
    for wd in web_dev:
        if wd in destination:
            return "Web Dev"
    return "Unknown"
df["course"] = df.destination.apply(get_topic)

# %%
df.course.value_counts()
# Out:
# Unknown         269982
# Web Dev         266456
# Data Science      7157
# Name: course, dtype: int64

# %%
df.destination.to_list()
# Out:
# ['/',
#  'java-ii',
#  'java-ii/object-oriented-programming',
#  'slides/object_oriented_programming',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/loops',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'javascript-i',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  'git/merge-conflict-demo',
#  'mkdocs/search_index.json',
#  'git/working-in-teams',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/functions',
#  '/',
#  'javascript-i',
#  '/',
#  'javascript-i/functions',
#  'javascript-i',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  '/',
#  'spring',
#  'javascript-i',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  '/',
#  'spring',
#  'appendix',
#  'spring/extra-features/file-upload',
#  'spring/extra-features/file-upload',
#  'appendix/capstone-workbook',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/objects/math',
#  '/',
#  'javascript-i',
#  'javascript-i/introduction/variables',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'index.html',
#  'java-i',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'javascript-i/functions',
#  '/',
#  'html-css/introduction',
#  'appendix',
#  'appendix/capstone-workbook',
#  'appendix/capstone-workbook',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/bom-and-dom',
#  'javascript-i/bom-and-dom/bom',
#  'appendix',
#  'appendix/capstone-workbook',
#  'javascript-i/conditionals',
#  'java-i',
#  'examples/javascript/defuse-the-bom.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/bom-and-dom/dom',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  '/',
#  'javascript-i',
#  'appendix',
#  'appendix/capstone-workbook',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'examples/javascript/dom-query-js.html',
#  '/',
#  'spring',
#  'spring/fundamentals/security/authentication',
#  'javascript/primitive-types',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'appendix/further-reading/javascript/hoisting.html',
#  '/',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix',
#  'mkdocs/search_index.json',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting',
#  'appendix/further-reading/javascript/hoisting',
#  'appendix/capstone-workbook',
#  'javascript-i',
#  'javascript-i/functions',
#  'appendix',
#  'appendix/further-reading/javascript/hoisting',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'appendix/further-reading/javascript/hoisting.html',
#  'mysql',
#  'appendix',
#  'appendix/capstone-workbook',
#  'appendix',
#  'appendix/capstone-workbook',
#  'javascript-i/functions',
#  'html-css',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'appendix',
#  'git/cli',
#  'javascript-i/functions',
#  'git/branching',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'spring/fundamentals/relationships',
#  'spring/fundamentals/repositories',
#  'javascript-i/bom-and-dom/dom-events',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  '/',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/arrays',
#  'mkdocs/search_index.json',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/variables',
#  'spring/fundamentals/relationships',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  '/',
#  'html-css',
#  'html-css/css-ii/grids',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/operators',
#  '/',
#  '/',
#  'mkdocs/search_index.json',
#  'content/javascript/objects/math.html',
#  'content/laravel/quickstart/sessions.html',
#  'appendix',
#  'appendix',
#  'appendix',
#  'appendix/capstone-workbook',
#  'javascript-i/conditionals',
#  'javascript-i/conditionals',
#  'appendix/documentation',
#  'appendix/postwork/beef-up-your-blog',
#  '/',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'appendix/capstone-workbook',
#  'examples/css/bootstrap-grids.html',
#  '/',
#  'appendix',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  'jquery/personal-site',
#  'javascript/google-maps-api',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'appendix',
#  'appendix/capstone-workbook',
#  '/',
#  'appendix',
#  'appendix/capstone-workbook',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'mysql',
#  'mysql/users',
#  'mysql/sample-database',
#  'javascript-i/introduction/operators',
#  'mysql/functions',
#  'mysql/group-by',
#  'mysql/aliases',
#  'javascript-i/introduction/variables',
#  'mysql/relationships/sub-queries',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'spring/extra-features/file-upload',
#  'spring/extra-features/file-upload',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/google-maps-api',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  '/',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/operators',
#  'mkdocs/search_index.json',
#  'spring',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  '/',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/introduction',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/loops',
#  '/',
#  '/',
#  '/',
#  'javascript-i',
#  '/',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/arrays',
#  'javascript-i/arrays/manipulating',
#  'javascript-i/objects',
#  'javascript-i/loops',
#  'javascript-i/functions',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'mkdocs/search_index.json',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'git/working-in-teams',
#  'appendix/postwork/memory-game',
#  'javascript-i/introduction/operators',
#  'appendix/postwork/beef-up-your-blog',
#  'spring',
#  'spring',
#  'spring',
#  '/',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'javascript-i/functions',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring',
#  'spring/fundamentals/controllers',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction',
#  'javascript-i/introduction/primitive-types',
#  '/',
#  'spring',
#  'spring',
#  'javascript-i/introduction/operators',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'spring/fundamentals/controllers',
#  'javascript-i/functions',
#  'mkdocs/search_index.json',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'appendix',
#  'git/intellij',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/conditionals',
#  'git/cli',
#  'javascript-i/functions',
#  'javascript-i/introduction/operators',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'spring/fundamentals/security',
#  'spring/extra-features/json-response',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/relationships',
#  'spring/fundamentals/security',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/repositories',
#  'spring',
#  'appendix/capstone-workbook',
#  'javascript-i/introduction/variables',
#  'mysql/aliases',
#  'mkdocs/search_index.json',
#  '/',
#  'javascript-i/introduction/operators',
#  'appendix',
#  'git/working-in-teams',
#  'spring',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'spring',
#  'appendix',
#  'spring',
#  '/',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  '/',
#  'spring/extra-features/form-validation',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/relationships',
#  'spring/fundamentals/security',
#  'spring',
#  'javascript-i/conditionals',
#  'spring/fundamentals/repositories',
#  'appendix/capstone-workbook',
#  '/',
#  'javascript/primitive-types',
#  'java',
#  '/',
#  'mysql/sample-database',
#  'mysql/intellij',
#  'mysql/sample-database',
#  '/',
#  'javascript-i/javascript-with-html',
#  'javascript-i/conditionals',
#  '/',
#  'mysql/relationships/joins',
#  'mysql/tables',
#  'mysql/databases',
#  'mysql/relationships',
#  'mysql/relationships/joins',
#  'mysql/relationships',
#  'mysql/database-design',
#  'mysql/relationships/indexes',
#  'spring/fundamentals/relationships',
#  '/',
#  'spring/extra-features/form-validation',
#  'spring/extra-features/error-pages',
#  'spring/extra-features/json-response',
#  'spring/extra-features/file-upload',
#  'spring/extra-features',
#  'spring/fundamentals/security/authentication',
#  'appendix/further-reading/spring/authorization',
#  'appendix/further-reading/spring/security-use-cases',
#  'javascript/primitive-types',
#  '/',
#  'appendix/further-reading/spring/security-use-cases',
#  'mkdocs/search_index.json',
#  'mysql/databases',
#  'mysql/tables',
#  'mysql/sample-database',
#  'javascript/primitive-types',
#  'spring/fundamentals/views',
#  'mysql/intellij',
#  'mysql/sample-database',
#  'mysql/sample-database',
#  'mysql/users',
#  'mysql/databases',
#  'mysql/tables',
#  'mysql/basic-statements',
#  'mysql/sample-database',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/repositories',
#  'spring',
#  'mysql/tables',
#  'javascript-i/functions',
#  'spring/fundamentals/controllers',
#  '/',
#  'appendix',
#  'appendix/documentation',
#  'appendix/further-reading/spring/seeder',
#  'appendix/further-reading/spring/devtools-configuration',
#  '/',
#  '/',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/relationships',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'spring/fundamentals/relationships',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/arrays',
#  'javascript-i/objects',
#  'javascript-i/objects/math',
#  'javascript-i/objects',
#  'javascript-i/bom-and-dom',
#  'javascript-i/bom-and-dom/bom',
#  'javascript-i/bom-and-dom/dom',
#  'javascript-i/bom-and-dom/dom-events',
#  'javascript-i/google-maps-api',
#  'javascript-i/coffee-project',
#  'javascript-i/functions',
#  'jquery',
#  'jquery/selectors',
#  'jquery/events',
#  'jquery/events/mouse-events',
#  'jquery/events/keyboard-events',
#  'jquery/essential-methods/attributes-and-css',
#  'jquery/essential-methods/traversing',
#  'jquery/effects',
#  'jquery/ajax',
#  'jquery/ajax/requests-and-responses',
#  'jquery/ajax/weather-map',
#  'jquery/ajax',
#  'jquery/ajax/weather-map',
#  'jquery/ajax/requests-and-responses',
#  'jquery/ajax/weather-map',
#  'jquery/simple-simon',
#  'jquery/personal-site',
#  'javascript-ii',
#  'javascript-ii/es6',
#  'javascript-ii/map-filter-reduce',
#  'javascript-ii/npm',
#  'javascript-ii/ajax-api',
#  'javascript-ii/modules',
#  'javascript-ii/ajax-api',
#  'java-i',
#  'java-i/introduction-to-java',
#  'javascript-i',
#  'javascript-i/functions',
#  '/',
#  'spring',
#  'spring/fundamentals/controllers',
#  '/',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/views',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'mysql/databases',
#  'mysql/tables',
#  '/',
#  'html-css/elements',
#  '/',
#  'javascript-i',
#  'javascript-i/loops',
#  'javascript-i/conditionals',
#  'spring/fundamentals/views',
#  '/',
#  '/',
#  'javascript-i/conditionals',
#  'spring/fundamentals/services',
#  '/',
#  'spring',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/services',
#  'spring/fundamentals/repositories',
#  'examples/css/bootstrap-grids.html',
#  '/',
#  'html-css/introduction',
#  'spring',
#  'spring/fundamentals/controllers',
#  '/',
#  'html-css',
#  'html-css/css-ii/bootstrap-introduction',
#  'html-css/css-ii/bootstrap-grid-system',
#  'html-css',
#  'html-css/elements',
#  'html-css/css-i/introduction',
#  'html-css/css-i/selectors-and-properties',
#  'spring/fundamentals/views',
#  'appendix',
#  'git/branching',
#  'spring',
#  'html-css/elements',
#  'html-css/css-i/selectors-and-properties',
#  'content/mysql/intro-to-mysql/users.html',
#  'content/html-css',
#  'content/html-css/elements.html',
#  'content/html-css/forms.html',
#  '/',
#  'html-css/introduction',
#  'teams/13',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  '/',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/relationships',
#  'spring/fundamentals/controllers',
#  'html-css/css-ii/bootstrap-grid-system',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/views',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/relationships',
#  '/',
#  'java-i',
#  'mysql',
#  'mysql/introduction',
#  'mysql/users',
#  'mysql/databases',
#  'mysql/tables',
#  'spring/fundamentals/relationships',
#  'mysql',
#  'mysql/users',
#  'mysql/databases',
#  'mysql/users',
#  'spring',
#  'spring/fundamentals/security',
#  'spring/fundamentals/security/authentication',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'appendix/code-standards/java',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'appendix/capstone-workbook',
#  'javascript-i/introduction/variables',
#  'appendix/capstone-workbook',
#  'spring',
#  'spring/fundamentals/relationships',
#  'html-css/css-ii/media-queries',
#  '/',
#  'html-css/css-i/positioning',
#  'html-css/css-ii/bootstrap-introduction',
#  'spring/fundamentals/views',
#  'spring/fundamentals/views',
#  'mkdocs/search_index.json',
#  'spring/fundamentals/services',
#  'mkdocs/search_index.json',
#  'appendix/capstone-workbook',
#  'content/html-css',
#  'content/html-css/introduction.html',
#  'content/html-css/elements.html',
#  'content/html-css/forms.html',
#  'content/git',
#  'content/git/creating-a-repository.html',
#  'content/git/initializing-a-repository.html',
#  'content/git/adding-files.html',
#  'content/git/committing.html',
#  'content/git/pushing-and-pulling.html',
#  'content/git/gitignore-file.html',
#  'content/git/branching.html',
#  'content/git/working-in-teams.html',
#  'content/javascript',
#  '/',
#  'content/html-css',
#  'content/html-css/introduction.html',
#  'content/html-css/elements.html',
#  'content/git/initializing-a-repository.html',
#  'content/git/adding-files.html',
#  'content/javascript',
#  'content/javascript/introduction-to-javascript.html',
#  'content/javascript/javascript-with-html.html',
#  'content/javascript_ii/es6.html',
#  'content/javascript_ii/map-filter-reduce.html',
#  'content/javascript_ii/promises.html',
#  '/',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  '/',
#  'content/javascript',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  '/',
#  'content/git/initializing-a-repository.html',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  '/',
#  'javascript-i/functions',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript/primitive-types',
#  '/',
#  'mkdocs/search_index.json',
#  'appendix/capstone-workbook',
#  '/',
#  '/',
#  'content/javascript/introduction-to-javascript.html',
#  'content/javascript/conditionals.html',
#  'content/javascript/loops.html',
#  'content/javascript_ii',
#  'content/javascript_ii/es6.html',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring',
#  'spring/fundamentals/controllers',
#  '/',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/functions',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/form-model-binding',
#  '/',
#  '/',
#  'spring/fundamentals/views',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-ii',
#  'javascript-ii/es6',
#  'javascript-ii/ajax-api',
#  'javascript-ii',
#  'jquery',
#  'javascript-i',
#  'javascript-i/functions',
#  'jquery',
#  'jquery/ajax/requests-and-responses',
#  'jquery/ajax/weather-map',
#  'javascript-i',
#  'javascript-i/google-maps-api',
#  'git/cli',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'java-i',
#  'java-i/introduction-to-java',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  '/',
#  'spring',
#  'spring/fundamentals/controllers',
#  '/',
#  'java-iii/passwords',
#  'slides/passwords',
#  'spring/fundamentals/views',
#  'appendix',
#  'appendix/further-reading/spring/devtools-configuration',
#  '/',
#  'javascript-i',
#  'javascript-i/objects',
#  'javascript-i/objects/math',
#  'javascript-i/bom-and-dom',
#  'javascript-i/bom-and-dom/bom',
#  'javascript-i/bom-and-dom/dom',
#  'javascript-i/bom-and-dom/dom-events',
#  'javascript-i/google-maps-api',
#  'javascript-i/coffee-project',
#  'jquery',
#  'jquery/effects',
#  'jquery/ajax',
#  'jquery/ajax/requests-and-responses',
#  'jquery/ajax/weather-map',
#  'jquery/simple-simon',
#  'jquery/personal-site',
#  '/',
#  'spring/fundamentals/relationships',
#  'appendix/further-reading/spring/seeder',
#  '/',
#  'mkdocs/search_index.json',
#  'jquery/ajax',
#  'jquery/ajax/requests-and-responses',
#  '/',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/introduction/variables',
#  '/',
#  'javascript-i/introduction',
#  'javascript-i/introduction/primitive-types',
#  '/',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  '/',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'appendix',
#  'javascript-i',
#  'appendix',
#  'html-css',
#  'html-css/introduction',
#  '/',
#  '/',
#  'html-css/elements',
#  'javascript-i/functions',
#  'html-css/forms',
#  'html-css/forms',
#  '/',
#  'spring/fundamentals/repositories',
#  'spring/fundamentals/form-model-binding',
#  'html-css/css-i',
#  'html-css/css-i/introduction',
#  'html-css/css-i/selectors-and-properties',
#  'html-css/css-i/box-model',
#  'html-css/css-i/positioning',
#  '/',
#  'java-iii',
#  'spring',
#  'spring/extra-features/json-response',
#  '/',
#  'java-iii',
#  '/',
#  'html-css/css-ii/bootstrap-grid-system',
#  'html-css/css-ii/bootstrap-introduction',
#  '/',
#  '/',
#  'javascript-i/introduction/primitive-types',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'content/php_i',
#  'content/php_i/intro-via-interactive-shell',
#  'content/gitbook/images/favicon.ico',
#  'content/php_i/intro-via-interactive-shell/hello-world-and-other-strings.html',
#  'content/php_i/intro-via-interactive-shell/doing-math-in-the-shell.html',
#  'content/php_ii',
#  'content/php_iii',
#  'content/php_iii/php-with-html',
#  'content/php_i/types-and-variables-i/introduction-to-strings.html',
#  'content/php_i/types-and-variables-ii/intro-to-strings-continued.html',
#  'content/php_i/types-and-variables-ii/objects-other-types-and-review.html',
#  'content/php_i/intro-to-operators',
#  'content/php_iii',
#  'content/php_iii/classes-and-objects-i',
#  '/',
#  'appendix',
#  'appendix/capstone-workbook',
#  '/',
#  'html-css/css-ii/media-queries',
#  'html-css/css-ii/bootstrap-grid-system',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/functions',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  '/',
#  'javascript-i/conditionals',
#  '/',
#  'javascript-i/introduction/operators',
#  'javascript-i/introduction/variables',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  'index.html',
#  'html-css',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/conditionals',
#  'spring',
#  'spring/fundamentals/controllers',
#  'spring/fundamentals/views',
#  'spring/fundamentals/services',
#  'spring/fundamentals/form-model-binding',
#  'spring/fundamentals/repositories',
#  'javascript-i/functions',
#  '/',
#  'spring',
#  'spring/extra-features/json-response',
#  '/',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/coffee-project',
#  'html-css',
#  'javascript-i/conditionals',
#  'javascript-ii',
#  'javascript-i',
#  'javascript-i/javascript-with-html',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'appendix/further-reading/javascript/hoisting.html',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'appendix/further-reading/javascript/hoisting.html',
#  'appendix/further-reading/javascript/hoisting',
#  'javascript-i',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/javascript-with-html',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  '/',
#  '/',
#  '/',
#  'html-css',
#  'html-css/introduction',
#  'html-css/elements',
#  'javascript-i',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  '/',
#  'javascript-i/introduction/working-with-data-types-operators-and-variables',
#  '/',
#  'spring/extra-features',
#  '/',
#  'mkdocs/search_index.json',
#  'appendix/capstone-workbook',
#  'git/intellij-intro',
#  'mkdocs/search_index.json',
#  'appendix/capstone-workbook',
#  'mkdocs/search_index.json',
#  'jquery/resume-portfolio',
#  '/',
#  '/',
#  'spring/fundamentals/security/authentication',
#  '/',
#  'spring/extra-features/form-validation',
#  'java-ii',
#  'javascript-i/functions',
#  'javascript-i/conditionals',
#  'javascript-i/loops',
#  'javascript-i/conditionals',
#  'java-ii/interfaces-and-abstract-classes',
#  'slides/interfaces_and_abstract_classes',
#  'html-css/forms',
#  'javascript-i/conditionals',
#  'javascript-i/conditionals',
#  'java-ii',
#  'slides/interfaces_and_abstract_classes',
#  '/',
#  'javascript-i/conditionals',
#  '/',
#  ...]

# %%
df.loc[df.destination == 'content/javascript']
# Out:
#          timestamp      time         destination  user  cohort  \
# 684     2018-01-27  15:56:13  content/javascript    51    13.0
# 691     2018-01-27  15:57:30  content/javascript    51    13.0
# 702     2018-01-27  16:09:05  content/javascript    51    13.0
# 4719    2018-02-02  22:50:59  content/javascript    80    14.0
# 4750    2018-02-03  00:07:55  content/javascript    51    13.0
# ...            ...       ...                 ...   ...     ...
# 440815  2020-01-28  11:23:16  content/javascript   545    28.0
# 519268  2020-04-20  21:01:01  content/javascript   646     8.0
# 521909  2020-04-23  09:56:06  content/javascript   646     8.0
# 521947  2020-04-23  10:12:44  content/javascript   646     8.0
# 543319  2020-05-15  12:49:55  content/javascript   647    14.0
#
#                      ip  huh   course
# 684       73.180.162.40  NaN  Web Dev
# 691       73.180.162.40  NaN  Web Dev
# 702       73.180.162.40  NaN  Web Dev
# 4719      137.51.30.194  NaN  Web Dev
# 4750      73.180.162.40  NaN  Web Dev
# ...                 ...  ...      ...
# 440815   13.107.209.195  NaN  Web Dev
# 519268  174.175.198.147  NaN  Web Dev
# 521909  174.175.198.147  NaN  Web Dev
# 521947  174.175.198.147  NaN  Web Dev
# 543319      71.115.4.79  NaN  Web Dev
#
# [124 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543595 entries, 0 to 543595
# Data columns (total 8 columns):
# timestamp      543595 non-null object
# time           543595 non-null object
# destination    543595 non-null object
# user           543595 non-null int64
# cohort         515739 non-null float64
# ip             543595 non-null object
# huh            0 non-null float64
# course         543595 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 37.3+ MB

# %%
df.cohort.nunique()
# Out:
# 36

# %%
df.loc[df.course == 'Data Science']
# Out:
#          timestamp      time                         destination  user  \
# 217602  2019-03-12  09:17:47          ada-python-assessment.html   366
# 218891  2019-03-14  08:50:02          ada-python-assessment.html   349
# 218895  2019-03-14  08:51:04          ada-python-assessment.html   349
# 218897  2019-03-14  08:55:27          ada-python-assessment.html   349
# 219534  2019-03-14  18:59:45          ada-python-assessment.html   351
# ...            ...       ...                                 ...   ...
# 542660  2020-05-14  17:00:51         4-python/8.3-intro-to-numpy   617
# 542662  2020-05-14  17:01:34      4-python/8.4.1-pandas-overview   617
# 542663  2020-05-14  17:02:40               4-python/8.4.2-series   617
# 542709  2020-05-14  18:30:46           4-python/8.4.3-dataframes   617
# 542745  2020-05-14  20:22:06  4-python/8.4.4-advanced-dataframes   617
#
#         cohort               ip  huh        course
# 217602     NaN     98.106.20.59  NaN  Data Science
# 218891     NaN     98.106.20.59  NaN  Data Science
# 218895     NaN     98.106.20.59  NaN  Data Science
# 218897     NaN     98.106.20.59  NaN  Data Science
# 219534     NaN  174.174.115.112  NaN  Data Science
# ...        ...              ...  ...           ...
# 542660    55.0    65.251.10.182  NaN  Data Science
# 542662    55.0    65.251.10.182  NaN  Data Science
# 542663    55.0    65.251.10.182  NaN  Data Science
# 542709    55.0    65.251.10.182  NaN  Data Science
# 542745    55.0    65.251.10.182  NaN  Data Science
#
# [7157 rows x 8 columns]

# %%
ip_df = pd.DataFrame(df.ip.value_counts(dropna=False)).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_count'})
ip_df2 = pd.DataFrame(df.ip.value_counts(dropna=False)/df.ip.count()).reset_index().\
                rename(index=str, columns={'index': 'ip', 'ip': 'ip_proba'})
ip_df = ip_df.merge(ip_df2)


# see those where rate < 1% 
ip_df[ip_df.ip_proba < .01]
# Out:
#                   ip  ip_count  ip_proba
# 3     13.107.209.195      4219  0.007761
# 4      173.125.68.94      2980  0.005482
# 5     77.186.132.227      1826  0.003359
# 6      137.51.33.152      1788  0.003289
# 7      68.12.137.147      1614  0.002969
# ...              ...       ...       ...
# 3490   108.78.220.35         1  0.000002
# 3491  65.158.242.247         1  0.000002
# 3492   173.59.110.81         1  0.000002
# 3493   69.202.241.18         1  0.000002
# 3494   41.133.253.75         1  0.000002
#
# [3492 rows x 3 columns]
